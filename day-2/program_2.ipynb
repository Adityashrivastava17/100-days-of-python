# %% [markdown]
# # Checking data type

# %%
x = 50
y = 60.5
z = "yash"
flag = False

print(type(x))
print(type(y))
print(type(z))
print(type(flag))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
