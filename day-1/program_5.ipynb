# %% [markdown]
# # Escape Sequence

# %%
print("python\tis\tfun")
print("line1\nline2\nline3")
print("She said, \"python is fun \"")
# Out:
# python	is	fun
# line1
# line2
# line3
# She said, "python is fun "
