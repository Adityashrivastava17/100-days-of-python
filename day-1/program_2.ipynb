# %% [markdown]
# # Multiple print statements

# %%
print("My name is yash")
print("I'm learning python")
print("Day 01 of 100 days of python")
# Out:
# My name is yash
# I'm learning python
# Day 01 of 100 days of python
